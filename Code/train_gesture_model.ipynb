# %% [markdown]
# # Train Gesture Model
#
# This notebook shows how to convert a folder of gesture videos/images into a landmark CSV using `convert_gesture_dataset.py`, then train a simple gesture classifier (mean+std aggregated MLP) using `train_gesture_model.py`.
#
# Replace the `INPUT_DIR` and `OUTPUT_CSV` paths with your dataset locations.

# %%
# 1) Convert dataset into landmarks CSV (run as shell command)
# Example (uncomment and set paths):
# !python Code/convert_gesture_dataset.py --input-dir /path/to/gesture_folders --output Dataset/Generated_Data/gestures.csv --recursive --step 2

print("To convert your dataset, run the shell command above with your paths.")

# %%
# 2) Train an aggregated MLP on the generated CSV
# Example (uncomment to run after conversion):
# !python Code/train_gesture_model.py --input Dataset/Generated_Data/gestures.csv --mode aggregate --out Models/gesture_mlp_agg.pkl

print("To train the aggregated MLP, run the shell command above after conversion.")

# %% [markdown]
# If you prefer to run training programmatically from this notebook (instead of shell), you can import `Code/train_gesture_model.py` functions after minor refactor. The CLI script is provided to keep things simple and reproducible.
